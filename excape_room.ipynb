# %%
#Game room
# define rooms and items

couch = {
    "name": "couch",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door"
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

piano = {
    "name": "piano",
    "type": "furniture",
}


game_room= {
    "name": "game room",
    "type": "room",
}


#Bedroom 1
# define rooms and items

door_b = {
    "name": "door b",
    "type": "door"
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

queen_bed = {
    "name": "queen bed",
    "type": "furniture",
}


door_c= {
    "name": "door c",
    "type": "door"
}

bedroom1 = {
    "name": "bedroom1",
    "type": "room",
}

#Living room
# define rooms and items

dining_table = {
    "name": "dining table",
    "type": "furniture",
}

door_d = {
    "name": "door d",
    "type": "door"
}


living_room = {
    "name": "living room",
    "type": "room",
}

outside = {
  "name": "outside"
}


#Bedroom 2
# define rooms and items

double_bed = {
    "name": "double bed",
    "type": "furniture",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}


key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

bedroom2 = {
    "name": "beedroom2",
    "type": "room",
}



all_rooms = [game_room, bedroom1, bedroom2, living_room, outside]

all_doors = [door_a, door_b, door_c, door_d]

object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "door a": [game_room,bedroom1 ],

    "bedroom_1" : [door_a, door_b, queen_bed, door_c],
    "queen bed" : [key_b],
    "door b" : [bedroom1, bedroom2],
    "door c" : [bedroom1, living_room],

    "bedroom 2": [double_bed, dresser],
    "double bed": [key_c],
    "dresser": [door_d],

    "living room" : [dining_table, door_d],
    "door d": [living_room, outside]
}



INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %%
print(key_d)
# Out:
# {'name': 'key for door d', 'type': 'key', 'target': {'name': 'door d', 'type': 'door'}}
